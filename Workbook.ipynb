# %%
import openai
import pandas as pd
from typing import List
import re
import numpy as np

# %%
def classify_sentiment(prompt: str) -> str:
    response = openai.Completion.create(
        engine="text-davinci-002",
        prompt=f"Classify the sentiment of the following sentence as 'neutral', 'negative', or 'super negative': \"{prompt}\"",
        max_tokens=20,
        n=1,
        stop=None,
        temperature=0.5,
    )

    sentiment = response.choices[0].text.strip()
    sentiment = re.search(r"neutral|negative|super negative", sentiment)
    return sentiment.group(0) if sentiment else "unknown"

# %%
df = pd.read_csv('./QTM350  Proposal Data.csv')

# %%
df
# Out:
#     Unnamed: 0                                              input  \
# 0            1                         I want to return something
# 1            2                     I'm calling for paying my bill
# 2            3                         I want to talk to an agent
# 3            4                             I need to file a claim
# 4            5         I'm calling for scheduling an installation
# 5            6               I have a question about your product
# 6            7                       I want to open a new account
# 7            8          I mean I want to speak with a real person
# 8            9  Can't you understand? I said I want my money b...
# 9           10                      Oh my god can someone help me
# 10          11  I don't want to repeat myself. I need to talk ...
# 11          12                           No I mean another thing!
# 12          13                   I don't know why it doesn't work
# 13          14  Just send me to someone who can solve me probl...
# 14          15  Can you just top repeating yourself and do som...
# 15          16                                  Ok fine I give up
# 16          17                                  Are you an idiot?
# 17          18             What the heck, just answer my question
# 18          19  Yeah blah blah blah can you just answer my que...
# 19          20  Why are you speaking with that tone just liste...
#
#          sentiment
# 0          neutral
# 1          neutral
# 2          neutral
# 3          neutral
# 4          neutral
# 5          neutral
# 6          neutral
# 7         negative
# 8         negative
# 9         negative
# 10        negative
# 11        negative
# 12        negative
# 13        negative
# 14  super negative
# 15  super negative
# 16  super negative
# 17  super negative
# 18  super negative
# 19  super negative

# %%
df['predicted_sentiment'] = df['input'].apply(classify_sentiment)

# %%
df
# Out:
#     Unnamed: 0                                              input  \
# 0            1                         I want to return something
# 1            2                     I'm calling for paying my bill
# 2            3                         I want to talk to an agent
# 3            4                             I need to file a claim
# 4            5         I'm calling for scheduling an installation
# 5            6               I have a question about your product
# 6            7                       I want to open a new account
# 7            8          I mean I want to speak with a real person
# 8            9  Can't you understand? I said I want my money b...
# 9           10                      Oh my god can someone help me
# 10          11  I don't want to repeat myself. I need to talk ...
# 11          12                           No I mean another thing!
# 12          13                   I don't know why it doesn't work
# 13          14  Just send me to someone who can solve me probl...
# 14          15  Can you just top repeating yourself and do som...
# 15          16                                  Ok fine I give up
# 16          17                                  Are you an idiot?
# 17          18             What the heck, just answer my question
# 18          19  Yeah blah blah blah can you just answer my que...
# 19          20  Why are you speaking with that tone just liste...
#
#          sentiment predicted_sentiment
# 0          neutral             neutral
# 1          neutral             neutral
# 2          neutral             neutral
# 3          neutral             neutral
# 4          neutral             neutral
# 5          neutral             neutral
# 6          neutral             neutral
# 7         negative            negative
# 8         negative      super negative
# 9         negative            negative
# 10        negative            negative
# 11        negative             neutral
# 12        negative            negative
# 13        negative            negative
# 14  super negative      super negative
# 15  super negative            negative
# 16  super negative            negative
# 17  super negative            negative
# 18  super negative      super negative
# 19  super negative      super negative

# %%
# Calculate overall accuracy
correct_predictions = np.sum(df['sentiment'] == df['predicted_sentiment'])
total_predictions = len(df)
overall_accuracy = correct_predictions / total_predictions

# Calculate accuracy within each category
categories = ['neutral', 'negative', 'super negative']
category_accuracies = {}

for category in categories:
    correct_category_predictions = np.sum((df['sentiment'] == df['predicted_sentiment']) & (df['sentiment'] == category))
    total_category_predictions = np.sum(df['sentiment'] == category)
    if total_category_predictions > 0:
        category_accuracy = correct_category_predictions / total_category_predictions
    else:
        category_accuracy = None
    category_accuracies[category] = category_accuracy

print(f"Overall accuracy: {overall_accuracy:.2f}")
for category, accuracy in category_accuracies.items():
    if accuracy is not None:
        print(f"Accuracy within '{category}' category: {accuracy:.2f}")
    else:
        print(f"No data for '{category}' category")
# Out:
# Overall accuracy: 0.75
# Accuracy within 'neutral' category: 1.00
# Accuracy within 'negative' category: 0.71
# Accuracy within 'super negative' category: 0.50
